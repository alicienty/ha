# %% [markdown]
# <a href="https://colab.research.google.com/github/alicienty/ha/blob/main/%D0%9B%D1%83%D0%BA%D1%8C%D1%8F%D0%BD%D1%87%D0%B8%D0%BA%D0%BE%D0%B2%D0%B0_RBMT_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание
# Лукьянчикова Алиса

# %% [markdown]
# Представьте, что вы работаете аналитиком в проекте по разработке системы машинного перевода. Ваша команда создает систему машинного перевода на основе правил. Прежде чем ваши коллеги приступят к разработке системы, вам, как аналитику, нужно описать архитектуру будущей системы.
#
# Опишите структуру своей системы машинного перевода на основе правила в формате псевдокода, алгоритма или блок-схемы (на выбор). В процессе работы вам нужно будет ответить на следующие вопросы:
#
# + Какую языковую пару обрабатывает ваша система?
# + Какие виды анализа и предварительной обработки данных вы применяете?
# + Какие языковые правила вам нужно описать?
# + Как ваша система будет генерировать результат, т.е. перевод?
#
# Дополнительно попробуйте ответить на вопрос:
#
# + Какие библиотеки NLP вы будете использовать?

# %% [markdown]
# **Языковая пара:** русский-польский
#
# **Алгоритм:**
# 1. Принимаем на вход текст пользователя (на русском языке)
# 2. Предобработка (библиотека nltk для токенизации, лемматизации, mystem для pos-теггинга)
#
#   2.1 Токенизация
#
#   2.2. Лемматизация
#
#   2.3. Удаление стоп-слов
#
#   2.4. POS-теггинг
# 3. Анализ синтаксиса (spaCy) – строим деревья зависимостей, чтобы рассчитывать, каким синтаксическим ролям вероятнее всего будет соответствовать слово
# 4. Применение языковых правил (определение функций, которые будут использоваться в генерации текста)
#
#   4.2. Согласование. Согласуем род, число и падеж между существительными и прилагательными, прописываем управление падежами для предлогов
#
#   4.3. Правила порядка слов. Применяем стандартный порядок слов для польского языка (SVO).
# 5. Генерация перевода
#
#   5.1. Формирование предложения на польском языке. Строим предложение с учетом синтаксических правил.
#
#   5.2. Постобработка. Корректируем грамматические ошибки и оптимизируем стиль перевода.
# 6. Вывод на экран перевода текста
